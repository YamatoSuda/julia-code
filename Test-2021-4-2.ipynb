# %%
using Plots

# %%
print("Hello world")
plot(
    x->x^3+x^2+x,
    xlabel="x",
    ylabel="y",
    label="y=x^3+y^2+x",
    xlims=(-3,3),
    ylims=(-10,10),
    xticks=-3:0.5:3,
    title="Test plot",
    linecolor=:blue,
    linewidth=3,
    linestyle=:dot,
)
# Out:
# Hello world

# %%
θ=(1+2im)*(2-3im)
η=(2-3im)*(4+1im)
Σ_int=θ+η^2
print(Σ_int)
# Out:
# 29 - 219im

# %%
a=1.0
plot(
    x->((sin(a*x)/(a*x)-cos(a*x))^2),
    xlim=(-10,10)
)
